# %%
import numpy as np
import gym

# %%
env = gym.make('FrozenLake', render_mode='human')  # Added render_mode
state_space_size = env.observation_space.n
action_space_size = env.action_space.n
q_table = np.zeros((state_space_size, action_space_size))
alpha = 0.1
gamma = 0.99
epsilon = 0.1


num_episodes = 1000

for episode in range(num_episodes):
    state = env.reset()
    action = env.action_space.sample()
    if np.random.rand() < epsilon
    else:
    np.argmax(q_table[state, :])
    while True:
        next_state, reward, done, _ = env.step(action)
        next_action = env.action_space.sample() if np.random.rand() < epsilon else np.argmax(q_table[next_state, :])
        q_table[state, action] += alpha * (reward + gamma * q_table[next_state, next_action] - q_table[state, action])
        state = next_state
        action = next_action
        if done:
            break
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-723ceaa3e6f2> in <cell line: 12>()
#      14     action = env.action_space.sample() if np.random.rand() < epsilon else np.argmax(q_table[state, :])
#      15     while True:
# ---> 16         next_state, reward, done, _ = env.step(action)
#      17         next_action = env.action_space.sample() if np.random.rand() < epsilon else np.argmax(q_table[next_state, :])
#      18         q_table[state, action] += alpha * (reward + gamma * q_table[next_state, next_action] - q_table[state, action])
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/time_limit.py in step(self, action)
#      58         """
#      59         observation, reward, terminated, truncated, info = step_api_compatibility(
# ---> 60             self.env.step(action),
#      61             True,
#      62         )
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/order_enforcing.py in step(self, action)
#      35         if not self._has_reset:
#      36             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37         return self.env.step(action)
#      38
#      39     def reset(self, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py in step(self, action)
#      50             (observation, reward, terminated, truncated, info) or (observation, reward, done, info)
#      51         """
# ---> 52         step_returns = self.env.step(action)
#      53         if self.new_step_api:
#      54             return step_to_new_api(step_returns)
#
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/env_checker.py in step(self, action)
#      37             return env_step_passive_checker(self.env, action)
#      38         else:
# ---> 39             return self.env.step(action)
#      40
#      41     def reset(self, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/gym/envs/toy_text/frozen_lake.py in step(self, a)
#     250         self.s = s
#     251         self.lastaction = a
# --> 252         self.renderer.render_step()
#     253         return (int(s), r, t, False, {"prob": p})
#     254
#
# /usr/local/lib/python3.10/dist-packages/gym/utils/renderer.py in render_step(self)
#      56         """
#      57         if self.mode is not None and self.mode not in self.single_render:
# ---> 58             render_return = self.render(self.mode)
#      59             if self.mode not in self.no_returns_render:
#      60                 self.render_list.append(render_return)
#
# /usr/local/lib/python3.10/dist-packages/gym/envs/toy_text/frozen_lake.py in _render(self, mode)
#     283             return self._render_text()
#     284         elif mode in {"human", "rgb_array", "single_rgb_array"}:
# --> 285             return self._render_gui(mode)
#     286
#     287     def _render_gui(self, mode):
#
# /usr/local/lib/python3.10/dist-packages/gym/envs/toy_text/frozen_lake.py in _render_gui(self, mode)
#     376             pygame.event.pump()
#     377             pygame.display.update()
# --> 378             self.clock.tick(self.metadata["render_fps"])
#     379         elif mode in {"rgb_array", "single_rgb_array"}:
#     380             return np.transpose(
#
# KeyboardInterrupt:
