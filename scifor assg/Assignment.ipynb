# %%
import numpy as np
import pandas as pd

# %%
# 1st question
a = np.arange(1,1001)
b=[]
for i in a:
   if i%100 == 0:
      b.append(i)
series = pd.Series(b)
series
# Out:
# 0     100
# 1     200
# 2     300
# 3     400
# 4     500
# 5     600
# 6     700
# 7     800
# 8     900
# 9    1000
# dtype: int64

# %%
data = {
    'Category': ['Electronics', 'Clothing', 'Books'],
    'Sub-category': ['Laptops', 'T-shirts', 'Fiction'],
    'Quantity': [10, 20, 15]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Category Sub-category  Quantity
# 0  Electronics      Laptops        10
# 1     Clothing     T-shirts        20
# 2        Books      Fiction        15

# %%
s=[110,105,85]
d=[112,106,86]
f=[113,107,87]
frame = pd.DataFrame([s,d,f])
frame
# Out:
#      0    1   2
# 0  110  105  85
# 1  112  106  86
# 2  113  107  87

# %%
income = pd.Series({'January': 50000, 'February': 55000, 'March': 60000})
expenditure= pd.Series({'January': 20000, 'February': 25000, 'March': 18000})
saving = income - expenditure


g = pd.DataFrame({'Income': income, 'Expenditure': expenditure, 'Savings': saving})

print(g)
# Out:
#           Income  Expenditure  Savings
# January    50000        20000    30000
# February   55000        25000    30000
# March      60000        18000    42000
