# %%
import nltk
import spacy

# %%
#stemming
from nltk.stem import PorterStemmer
stemming= PorterStemmer()
nlp = spacy.blank('en')
words = nlp('it has been raining since last night')
for word in words:
  print(stemming.stem(word))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4840f80c8cb3> in <cell line: 6>()
#       5 words = nlp('it has been raining since last night')
#       6 for word in words:
# ----> 7   print(stemming.stem(word))
#
# /usr/local/lib/python3.10/dist-packages/nltk/stem/porter.py in stem(self, word, to_lowercase)
#     656         :param to_lowercase: if `to_lowercase=True` the word always lowercase
#     657         """
# --> 658         stem = word.lower() if to_lowercase else word
#     659
#     660         if self.mode == self.NLTK_EXTENSIONS and word in self.pool:
#
# TypeError: 'int' object is not callable
