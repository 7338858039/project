# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('/content/data.xlsx')
df.head()
# Out:
#                     Series Name     Series Code                 Country Name  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD                  Afghanistan
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD  Africa Eastern and Southern
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD   Africa Western and Central
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD                      Albania
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD                      Algeria
#
#   Country Code 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# 0          AFG    651.987862    628.146804    592.476165    520.251955
# 1          AFE   1736.222507   1724.534381   1545.559084   1436.094404
# 2          AFW   2153.766138   2247.857492   1880.750778   1646.972399
# 3          ALB   4413.063397   4578.633208   3952.803584    4124.05539
# 4          DZA   5519.777576   5516.229463   4197.419971    3967.20066
#
#   2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1596 entries, 0 to 1595
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series Name    1596 non-null   object
#  1   Series Code    1596 non-null   object
#  2   Country Name   1596 non-null   object
#  3   Country Code   1596 non-null   object
#  4   2013 [YR2013]  1596 non-null   object
#  5   2014 [YR2014]  1596 non-null   object
#  6   2015 [YR2015]  1596 non-null   object
#  7   2016 [YR2016]  1596 non-null   object
#  8   2017 [YR2017]  1596 non-null   object
#  9   2018 [YR2018]  1596 non-null   object
#  10  2019 [YR2019]  1596 non-null   object
#  11  2020 [YR2020]  1596 non-null   object
#  12  2021 [YR2021]  1596 non-null   object
#  13  2022 [YR2022]  1596 non-null   object
# dtypes: object(14)
# memory usage: 187.0+ KB

# %%
df.isnull().sum()
# Out:
# Series Name      3
# Series Code      5
# Country Name     5
# Country Code     5
# 2013 [YR2013]    5
# 2014 [YR2014]    5
# 2015 [YR2015]    5
# 2016 [YR2016]    5
# 2017 [YR2017]    5
# 2018 [YR2018]    5
# 2019 [YR2019]    5
# 2020 [YR2020]    5
# 2021 [YR2021]    5
# 2022 [YR2022]    5
# dtype: int64

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]',
#        '2021 [YR2021]', '2022 [YR2022]'],
#       dtype='object')

# %%
df['Series Name'] = df['Series Name'].astype('str')

# %%
df['Series Name'].value_counts()
# Out:
# GDP per capita (current US$)                                                                          266
# Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)    266
# Population density (people per sq. km of land area)                                                   266
# Literacy rate, adult female (% of females ages 15 and above)                                          266
# Maternal mortality ratio (modeled estimate, per 100,000 live births)                                  266
# Mortality rate, under-5 (per 1,000 live births)                                                       266
# Name: Series Name, dtype: int64

# %%
# Select values population density and maternal morality
df[(df['Series Name'] == "Population density (people per sq. km of land area)")|(df['Series Name'] == "Maternal mortality ratio (modeled estimate, per 100,000 live births)")].head()
# Out:
#                                            Series Name  Series Code  \
# 532  Population density (people per sq. km of land ...  EN.POP.DNST
# 533  Population density (people per sq. km of land ...  EN.POP.DNST
# 534  Population density (people per sq. km of land ...  EN.POP.DNST
# 535  Population density (people per sq. km of land ...  EN.POP.DNST
# 536  Population density (people per sq. km of land ...  EN.POP.DNST
#
#                     Country Name Country Code 2013 [YR2013] 2014 [YR2014]  \
# 532                  Afghanistan          AFG     48.359028     50.160542
# 533  Africa Eastern and Southern          AFE      38.25452     39.316203
# 534   Africa Western and Central          AFW     42.804993     43.982443
# 535                      Albania          ALB    105.660292    105.441752
# 536                      Algeria          DZA     15.954985     16.273887
#
#     2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# ...

# %%
# Plot the graph between education and population density.
a = df[(df['Series Name'] == "Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)")].shape[0]
b = df[(df['Series Name'] == "Population density (people per sq. km of land area)")].shape[0]
x_value = ["Educational attainment, at least Bachelor's or equivalent, population 25+, female (%) (cumulative)","Population density (people per sq. km of land area)"]

sns.barplot(data = df,x=x_value,y=[a,b])
# Out:
# <Axes: >

# %%
# Print the complete dataset in DataFrame.
df.head()
# Out:
#                     Series Name     Series Code                 Country Name  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD                  Afghanistan
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD  Africa Eastern and Southern
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD   Africa Western and Central
# 3  GDP per capita (current US$)  NY.GDP.PCAP.CD                      Albania
# 4  GDP per capita (current US$)  NY.GDP.PCAP.CD                      Algeria
#
#   Country Code 2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016]  \
# 0          AFG    651.987862    628.146804    592.476165    520.251955
# 1          AFE   1736.222507   1724.534381   1545.559084   1436.094404
# 2          AFW   2153.766138   2247.857492   1880.750778   1646.972399
# 3          ALB   4413.063397   4578.633208   3952.803584    4124.05539
# 4          DZA   5519.777576   5516.229463   4197.419971    3967.20066
#
#   2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021]  \
# ...
