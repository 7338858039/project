# %%
import numpy as np
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
a = datasets.load_diabetes()

# %%
df = pd.DataFrame(data = a.data,columns= a.feature_names)
df['target'] = a.target
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.corr()
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex     0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi     0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp      0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1      0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2      0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3     -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4      0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5      0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6      0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
# target  0.187889  0.043062  0.586450  0.441482  0.212022  0.174054 -0.394789
#
#               s4        s5        s6    target
# age     0.203841  0.270774  0.301731  0.187889
# sex     0.332115  0.149916  0.208133  0.043062
# bmi     0.413807  0.446157  0.388680  0.586450
# bp      0.257650  0.393480  0.390430  0.441482
# s1      0.542207  0.515503  0.325717  0.212022
# s2      0.659817  0.318357  0.290600  0.174054
# s3     -0.738493 -0.398577 -0.273697 -0.394789
# s4      1.000000  0.617859  0.417212  0.430453
# s5      0.617859  1.000000  0.464669  0.565883
# s6      0.417212  0.464669  1.000000  0.382483
# target  0.430453  0.565883  0.382483  1.000000

# %%
df =df.dropna()

# %%
x = df.loc[:,'age':'s6']
y = df.loc[:,'target']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
predict= model.predict(x_test)

# %%
y_test
# Out:
# 362    321.0
# 249    215.0
# 271    127.0
# 435     64.0
# 400    175.0
#        ...
# 381    104.0
# 213     49.0
# 134    103.0
# 49     142.0
# 52      59.0
# Name: target, Length: 89, dtype: float64

# %%
predict
# Out:
# array([235.29941812, 245.15862773, 164.33017386, 119.48376601,
#        187.18494664, 251.35815403, 115.06915952, 189.19505093,
#        142.51704894, 228.58539684, 166.82164929, 178.55406527,
#        106.8371012 ,  88.10194612, 244.30103923,  85.80068961,
#        155.22669143,  68.07103297,  97.07481511, 222.4833913 ,
#        191.16896496, 157.87641942, 163.01540596, 150.50028158,
#        191.33777472, 168.21372017, 129.83145265,  87.12170524,
#        193.31578983, 160.67104137, 180.13082199,  84.17319946,
#        142.20991224, 144.42614949, 146.64558568, 196.91468873,
#        165.84386951, 190.66218796, 131.09296884, 206.7587966 ,
#         85.25913019, 165.38480498, 146.2718871 , 182.31148421,
#        178.70270016,  76.80052219, 146.99841953, 139.11104979,
#        124.02163345, 236.71054289, 159.93677518,  73.89134662,
#        157.03297709, 157.01450004, 235.16173729, 177.17487964,
#        191.53493643, 114.23552012, 139.54451791, 170.44330954,
#        207.82676612, 169.23118221, 155.67052006, 113.03485904,
#        246.29432383, 150.64748328,  82.1730808 , 230.55961445,
#        197.47424761,  53.44727472,  79.93968011, 134.57871054,
#        104.57681546, 143.05684078, 129.84290324, 189.95771575,
#        101.05581371, 199.01879825, 219.35193167, 189.19166962,
#        154.59985312, 207.72402726,  46.59651844, 207.99702587,
#         74.67587343,  98.58135665, 141.69639374, 189.87117754,
#        134.1851441 ])

# %%
df1= pd.DataFrame({'bmi':x_test['bmi'],'Actual':y_test,'Pred':predict})
df1.head()
# Out:
#           bmi  Actual        Pred
# 362  0.104809   321.0  235.299418
# 249  0.060618   215.0  245.158628
# 271  0.008883   127.0  164.330174
# 435 -0.023451    64.0  119.483766
# 400  0.045529   175.0  187.184947

# %%
sns.regplot(data = df1,x='bmi',y = 'Actual')
# Out:
# <Axes: xlabel='bmi', ylabel='Actual'>
